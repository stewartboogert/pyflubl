# %%
import sys
sys.path.insert(0, '../')

import pyflubl
import matplotlib.pyplot as plt
import test_T051_Lattice
# Out:
# initializing ocelot...

# %%
d = pyflubl.Analysis.openFile("./T051_Lattice_Quad001_dump","usrdump")
#m = test_T051_Lattice.make_T051_Lattice_Quadrupole()

# %%
d.read_event(0)
pyflubl.Analysis.plot_coordinates_projection(m,"zy")
pyflubl.Analysis.plot_usrdump(d,"zy")
plt.ylim(-250,250)
#plt.xlim(1000,1500)
# Out:
# (-250.0, 250.0)
