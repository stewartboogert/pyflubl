# %%
import sys
sys.path.insert(0, '../')

import matplotlib.pyplot as plt
import pyflubl
import test_T017_Target
import uproot
import numpy
import awkward as ak

# %%
m = test_T017_Target.make_T017_target_circular()
d = pyflubl.Analysis.openFile("./T017_Target_circular001_dump","usrdump")

# %%
pyflubl.Analysis.plot_coordinates(m)

# %%
d.read_event(0)
pyflubl.Analysis.plot_coordinates_projection(m,"zx")
pyflubl.Analysis.plot_usrdump(d,"zx")

# %%
bk = pyflubl.Analysis.openBookkeepingFile("./pyflubl.json")
list(bk['samplernames_samplernumber'].keys())

trees = [uproot.open(f)["event"] for f in ["T017_Target000_pyflubl.root"]]

arrays = [tree["s1.x"].array() for tree in trees]
s1_x_all = numpy.ravel(ak.concatenate(arrays))

arrays = [tree["s1.y"].array() for tree in trees]
s1_y_all = numpy.ravel(ak.concatenate(arrays))


arrays = [tree["s2.x"].array() for tree in trees]
s2_x_all = numpy.ravel(ak.concatenate(arrays))

arrays = [tree["s2.y"].array() for tree in trees]
s2_y_all = numpy.ravel(ak.concatenate(arrays))

plt.subplot(2,2,1)
plt.hist(s1_x_all,100);

plt.subplot(2,2,2)
plt.hist(s1_y_all,100);

plt.subplot(2,2,3)
plt.hist(s2_x_all,100);

plt.subplot(2,2,4)
plt.hist(s2_y_all,100);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 bk = pyflubl.Analysis.openBookkeepingFile("./pyflubl.json")
#       2 list(bk['samplernames_samplernumber'].keys())
# ----> 4 trees = [uproot.open(f)["event"] for f in ["T017_Target000_pyflubl.root"]]
#       6 arrays = [tree["s1.x"].array() for tree in trees]
#       7 s1_x_all = numpy.ravel(ak.concatenate(arrays))
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/uproot/reading.py:144, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     135 if not isinstance(file_path, str) and not (
#     136     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     137 ):
#     138     raise ValueError(
#     139         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     140         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     141         f"not {path!r}"
#     142     )
# --> 144 file = ReadOnlyFile(
#     145     file_path,
#     146     object_cache=object_cache,
#     147     array_cache=array_cache,
#     148     custom_classes=custom_classes,
#     149     decompression_executor=decompression_executor,
#     150     interpretation_executor=interpretation_executor,
#     151     **options,
#     152 )
#     154 if object_path is None:
#     155     return file.root_directory
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/uproot/reading.py:575, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     567 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#     568     raise ValueError(
#     569         "begin_chunk_size={} is not enough to read the TFile header ({})".format(
#     570             self._options["begin_chunk_size"],
#     571             _file_header_fields_big.size,
#     572         )
#     573     )
# --> 575 self._begin_chunk = self._source.chunk(
#     576     0, self._options["begin_chunk_size"]
#     577 ).detach_memmap()
#     579 self.hook_before_interpret()
#     581 (
#     582     magic,
#     583     self._fVersion,
#    (...)    597     self._begin_chunk, _file_header_fields_small, {}
#     598 )
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/uproot/source/fsspec.py:110, in FSSpecSource.chunk(self, start, stop)
#     108 self._num_requested_chunks += 1
#     109 self._num_requested_bytes += stop - start
# --> 110 data = self._fs.cat_file(self._file_path, start=start, end=stop)
#     111 future = uproot.source.futures.TrivialFuture(data)
#     112 return uproot.source.chunk.Chunk(self, start, stop, future)
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/fsspec/spec.py:805, in AbstractFileSystem.cat_file(self, path, start, end, **kwargs)
#     793 """Get the content of a file
#     794
#     795 Parameters
#    (...)    802 kwargs: passed to ``open()``.
#     803 """
#     804 # explicitly set buffering off?
# --> 805 with self.open(path, "rb", **kwargs) as f:
#     806     if start is not None:
#     807         if start >= 0:
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/fsspec/spec.py:1352, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1350 else:
#    1351     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1352     f = self._open(
#    1353         path,
#    1354         mode=mode,
#    1355         block_size=block_size,
#    1356         autocommit=ac,
#    1357         cache_options=cache_options,
#    1358         **kwargs,
#    1359     )
#    1360     if compression is not None:
#    1361         from fsspec.compression import compr
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/fsspec/implementations/local.py:214, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     212 if self.auto_mkdir and "w" in mode:
#     213     self.makedirs(self._parent(path), exist_ok=True)
# --> 214 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/fsspec/implementations/local.py:391, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     389 self.compression = get_compression(path, compression)
#     390 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 391 self._open()
#
# File ~/miniconda3/envs/phys-py312/lib/python3.12/site-packages/fsspec/implementations/local.py:396, in LocalFileOpener._open(self)
#     394 if self.f is None or self.f.closed:
#     395     if self.autocommit or "w" not in self.mode:
# --> 396         self.f = open(self.path, mode=self.mode)
#     397         if self.compression:
#     398             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/stewart.boogert/Dropbox/Physics/coderepos/bdsim/bdsim-organisation/pyflubl/test/pyflubl/run_T017_Target/T017_Target000_pyflubl.root'
