# %%
import sys
sys.path.insert(0, '../')

import pyflubl
import matplotlib.pyplot as plt
import test_T051_Lattice
# Out:
# initializing ocelot...

# %%
d = pyflubl.Analysis.openFile("./T051_Lattice_SBend_simple001_dump","usrdump")
m = test_T051_Lattice.make_T051_Lattice_SBend_simple()

# %%
pyflubl.Analysis.plot_coordinates_projection(m,"zx")
i=20
for i in range(i,i+1) :
    print(i)
    d.read_event(i)
    pyflubl.Analysis.plot_usrdump(d,"zx",linewidth=1, markersize=2)
#plt.xlim(2000,3000)
#plt.ylim(-500,500)
# Out:
# 20
