# %%
import sys
sys.path.insert(0, '../')

import pyflubl
import matplotlib.pyplot as plt
import test_T051_Lattice
# Out:
# initializing ocelot...

# %%
d = pyflubl.Analysis.openFile("./T051_Lattice_SBend001_dump","usrdump")
m = test_T051_Lattice.make_T051_Lattice_SBend()
# Out:
# Region does not have an assigned material R0003
# Region does not have an assigned material R0007
# Region does not have an assigned material R0008
# Region does not have an assigned material R0009
# Region does not have an assigned material R0010
# Region does not have an assigned material R0011
# Region does not have an assigned material R0012
# Region does not have an assigned material R0013
# Region does not have an assigned material R0014
# Region does not have an assigned material R0015
# Region does not have an assigned material R0016
# Region does not have an assigned material R0020
# Region does not have an assigned material R0021
# Region does not have an assigned material R0022
# Region does not have an assigned material R0023
# Region does not have an assigned material R0024
# Region does not have an assigned material R0025
# Region does not have an assigned material R0026
# Region does not have an assigned material R0027
# Region does not have an assigned material R0028

# %%
d.read_event(0)
pyflubl.Analysis.plot_coordinates_projection(m,"zx")
pyflubl.Analysis.plot_usrdump(d,"zx")
#plt.xlim(500,2500)
#plt.ylim(-250,250)
